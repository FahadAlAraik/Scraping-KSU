# %%
pip install --upgrade chromedriver-autoinstaller
# Out:
# Requirement already satisfied: chromedriver-autoinstaller in c:\users\desktop-1\anaconda3\lib\site-packages (0.4.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -cipy (c:\users\desktop-1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\desktop-1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\desktop-1\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\desktop-1\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# RUN THIS FOR CHROME DRIVER INSTALLER
import chromedriver_autoinstaller as chromedriver
chromedriver.install()

# %%
from helium import *
import time
import numpy as np
import pandas as pd
import re
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import threading

# %% [markdown]
# # Functions To Extract Scraped Data

# %%
def handle_row_one_bigger(row1,row2):
    counter = len(row1) + len(row2)
    courses_of_row1 = [item.web_element.text for item in row1]
    courses_of_row2 = [item.web_element.text for item in row2]
    
    temp = pd.DataFrame({'course_code':[],'course_name':[],'section_number':[],'course_type':[],
                        'course_hours':[],'course_gender':[]})
    
    for i in range(len(courses_of_row1)-1):
        temp_lecture_df = Extracter(courses_of_row1[i])
        temp_tutorial_df = Extracter(courses_of_row2[i])
        temp = pd.concat([temp,temp_lecture_df])
        temp = pd.concat([temp,temp_tutorial_df])
    temp= temp.append(Extracter(courses_of_row1[-1]))
    return temp

# %%
def handle_row_two_bigger(row1,row2):
    counter = len(row1) + len(row2)
    courses_of_row1 = [item.web_element.text for item in row1]
    courses_of_row2 = [item.web_element.text for item in row2]
    
    temp = pd.DataFrame({'course_code':[],'course_name':[],'section_number':[],'course_type':[],
                        'course_hours':[],'course_gender':[]})
    
    for i in range(len(courses_of_row2)-1):
        temp_lecture_df = Extracter(courses_of_row1[i])
        temp_tutorial_df = Extracter(courses_of_row2[i])
        temp = pd.concat([temp,temp_tutorial_df])
        temp = pd.concat([temp,temp_lecture_df])
        
    temp= temp.append(Extracter(courses_of_row2[-1]))
    return temp

# %%
def Extracter(row):
   
    #Lecture extracter
    row=row.split(" ")
    if row[-5] == "محاضرة" or row[-5] == 'تدريب' or row[-5] == 'مشروع':
        course_code = row[0] +" "+ row[1]
        course_name = " ".join(row[2:-6])
        section_number = row[-6]
        course_type = row[-5]
        course_hours = row[-4]
        course_gender = row[-3]
        temp_df = pd.DataFrame({'course_code':[course_code],'course_name':[course_name],'section_number':[section_number],
                                'course_type':[course_type],'course_hours':[course_hours],'course_gender':[course_gender],
                               },index=[0])
        #print(temp_df)
        return temp_df
    
    elif row[-4] == 'تمارين' or row[-4] == "عملي":
        course_code = row[0] +" "+ row[1]
        course_name = " ".join(row[2:-5])
        section_number = row[-5]
        course_type = row[-4]
        course_hours = row[-3]
        course_gender = row[-2]
        temp_df  = pd.DataFrame({'course_code':[course_code],'course_name':[course_name],'section_number':[section_number],
                                'course_type':[course_type],'course_hours':[course_hours],'course_gender':[course_gender]},index=[0])
        return temp_df
    
    else:
        temp_df = pd.DataFrame({'course_code':['redundant'],'course_name':['redundant'],'section_number':['redundant'],'course_type':['redundant'],
                          'course_hours':['redundant'],'course_gender':['redundant']})
        return temp_df

# %%
def ExtractCourseDayAndDuration(array):
    text = array
    time_regex = re.compile(r'\d{2}:\d{2}(?: [صم])')
    timeOfCourse = []
    for i in text:
        result = re.findall(time_regex,i)
        if not len(result) == 0:
            for i in result:
                if i not in timeOfCourse:
                    timeOfCourse.append(i)
                
    return timeOfCourse

# %%
def ExtractCourseDay(text):
    digits_only = re.findall('\d', text)
    return digits_only

# %% [markdown]
# # Scraping KSU Content

# %%
courses_df = pd.DataFrame({'course_code':[],'course_name':[],'section_number':[],'course_type':[],
                          'course_hours':[],'course_gender':[]})

# %%
finals_df = pd.DataFrame({'course_day':[],'course_time':[],'final_exam_day':[],
                          'final_exam_date':[],'final_exam_time':[],'lecturer':[]})

# %% [markdown]
# # Scraping Course Content Only (Courses Section,and tutorials)

# %%
start_chrome()
go_to("https://edugate.ksu.edu.sa/ksu/ui/guest/timetable/index/mainScheduleTreeCoursesIndex.faces")
time.sleep(1)
click(Link("المقررات المطروحة",above="المقررات المطروحة - بحث متقدم")) 
time.sleep(1)
college_name = 'علوم الحاسب والمعلومات' # <-- Change Based On Your College Name
click("علوم الحاسب والمعلومات") 
time.sleep(1)
major_name = "هندسة الحاسب" # <-- Change Based on the major you want to scrape
click(major_name) 
time.sleep(1)
major_plan = "CENN-هندسة الحاسب"
click(major_plan) # <-- Change Based on the major plan
time.sleep(1)
click("إبحث")

nbPages = 56 # <-- PLEASE NOTE CHANGE BASED ON THE MAJOR NUMBER OF PAGES
while 1 < nbPages: 
    
    # Get all of the courses 
    time.sleep(1)
    row1 = find_all(S('.ROW1'))
    row2 = find_all(S('.ROW2'))
    time.sleep(1)

    if len(row1) > len(row2):
        courses_df = courses_df.append(handle_row_one_bigger(row1,row2))
    
    else:
        courses_df = courses_df.append(handle_row_two_bigger(row1,row2))
    
    row = None
        
    counter +=1
    row1 = []
    row2  = []
    click(S(".pui-paginator-next"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13296\2118913879.py in <module>
#      17     # Get all of the courses
#      18     time.sleep(1)
# ---> 19     row1 = find_all(S('.ROW1'))
#      20     row2 = find_all(S('.ROW2'))
#      21     time.sleep(1)
#
# ~\anaconda3\lib\site-packages\helium\__init__.py in find_all(predicate)
#     361                 leftmost_button = sorted(buttons, key=lambda button: button.x)[0]
#     362 	"""
# --> 363         return _get_api_impl().find_all_impl(predicate)
#     364
#     365 def scroll_down(num_pixels=100):
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in f_decorated(*args, **kwargs)
#      54         def f_decorated(*args, **kwargs):
#      55                 try:
# ---> 56                         return f(*args, **kwargs)
#      57                 except UnexpectedAlertPresentException:
#      58 			raise UnexpectedAlertPresentException(
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in find_all_impl(self, predicate)
#     267         @handle_unexpected_alert
#     268         def find_all_impl(self, predicate):
# --> 269 		return [
#     270                         predicate.with_impl(bound_gui_elt_impl)
#     271                         for bound_gui_elt_impl in predicate._impl.find_all()
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in <listcomp>(.0)
#     267         @handle_unexpected_alert
#     268         def find_all_impl(self, predicate):
# --> 269 		return [
#     270                         predicate.with_impl(bound_gui_elt_impl)
#     271                         for bound_gui_elt_impl in predicate._impl.find_all()
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in find_all(self)
#     614                         yield self
#     615                 else:
# --> 616                         for occurrence in self.find_all_occurrences():
#     617                                 yield self.bound_to_occurrence(occurrence)
#     618         def _is_bound(self):
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in find_all_occurrences(self)
#     721                                 search_regions = self._get_search_regions_in_curr_frame()
#     722                                 for occurrence in self.find_all_in_curr_frame():
# --> 723                                         if self._should_yield(occurrence, search_regions):
#     724                                                 occurrence.frame_index = frame_index
#     725                                                 yield occurrence
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in _should_yield(self, occurrence, search_regions)
#     761                 return result
#     762         def _should_yield(self, occurrence, search_regions):
# --> 763                 return occurrence.is_displayed() and \
#     764                            self._is_in_any_search_region(occurrence, search_regions)
#     765         def _is_in_any_search_region(self, element, search_regions):
#
# ~\anaconda3\lib\site-packages\helium\_impl\selenium_wrappers.py in is_displayed(self)
#     113         def is_displayed(self):
#     114                 try:
# --> 115 			return self.target.is_displayed() and self.location.intersects(
#     116                                 Rectangle(0, 0, sys.maxsize, sys.maxsize)
#     117 			)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in is_displayed(self)
#     484         # Only go into this conditional for browsers that don't use the atom themselves
#     485         if self._w3c:
# --> 486             return self.parent.execute_script(
#     487                 "return (%s).apply(null, arguments);" % isDisplayed_js,
#     488                 self)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     632             command = Command.EXECUTE_SCRIPT
#     633
# --> 634         return self.execute(command, {
#     635             'script': script,
#     636             'args': converted_args})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# ~\anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# ~\anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     374             response = conn.urlopen(method, url, **kw)
#     375         else:
# --> 376             response = conn.urlopen(method, u.request_uri, **kw)
#     377
#     378         redirect_location = redirect and response.get_redirect_location()
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
courses_df.head()
# Out:
#   course_code  course_name section_number course_type course_hours  \
# 0     227 عال  نظم التشغيل          12320      محاضرة            3
# 0     227 عال  نظم التشغيل          12321      تمارين          ذكر
# 0     227 عال  نظم التشغيل          12328      محاضرة            3
# 0     227 عال  نظم التشغيل          12329      تمارين          ذكر
# 0     227 عال  نظم التشغيل          35605      محاضرة            3
#
#   course_gender
# 0           ذكر
# 0         مغلقة
# 0           ذكر
# 0         مغلقة
# 0           ذكر

# %%
start_chrome()
go_to("https://edugate.ksu.edu.sa/ksu/ui/guest/timetable/index/mainScheduleTreeCoursesIndex.faces")
time.sleep(1)
click(Link("المقررات المطروحة",above="المقررات المطروحة - بحث متقدم")) 
time.sleep(1)
college_name = 'علوم الحاسب والمعلومات' # <-- Change Based On Your College Name
click("علوم الحاسب والمعلومات") 
time.sleep(1)
major_name = "هندسة الحاسب" # <-- Change Based on the major you want to scrape
click(major_name) 
time.sleep(1)
major_plan = "CENN-هندسة الحاسب"
click(major_plan) # <-- Change Based on the major plan
time.sleep(1)
click("إبحث")

nbPages = 56 # <-- PLEASE NOTE CHANGE BASED ON THE MAJOR NUMBER OF PAGES
while 1 < nbPages: 
    
    # Get Final Exam, Course Day and Course Time
    time.sleep(1)
    links = find_all((Link("التفاصيل")))
    time.sleep(1)
    pattern = r"\d+"
    first = str(links[0])
    # find all occurrences of the pattern in the text
    firstInList = int(re.findall(pattern, first)[0])
    second = str(links[-1])
    secondInList = int(re.findall(pattern,second)[0])
    #print the matches
    
    row = None
    if firstInList>secondInList:
        for i in reversed(links):
            time.sleep(1)
            click(i)
            time.sleep(1)
            courseDay = find_all(S("#sectionDiv > table > tbody > tr > td > nobr",below='اليوم'))
            courseTime = find_all(S("#sectionDiv > table > tbody > tr > td > nobr",below='الوقت'))
            courseDay = [item.web_element.text for item in courseDay]
            courseTime = [item.web_element.text for item in courseTime]
            #instructorDiv
            examDay = [item.web_element.text for item in find_all(S("#examDayDiv"))]
            examTime = [item.web_element.text for item in find_all(S("#examTimeDiv"))]
            examDate = [item.web_element.text for item in find_all(S("#examDateDiv"))]
            lecturer = [item.web_element.text for item in find_all(S("#instructorDiv"))]
            temp_df = pd.DataFrame({'course_day':[courseDay],'course_time':[courseTime],
            'final_exam_day':[examDay[0]], 'final_exam_date':[examDate[0]],'final_exam_time':[examTime[0]],
                                   'lecturer':[lecturer]})
        
            time.sleep(1)
            finals_df = pd.concat([finals_df,temp_df])
            click(S(".ui-icon-close"))
        
    else:
        
        for i in links:
            time.sleep(1)
            click(i)
            time.sleep(1)
            courseDay = find_all(S("#sectionDiv > table > tbody > tr > td > nobr",below='اليوم'))
            courseTime = find_all(S("#sectionDiv > table > tbody > tr > td > nobr",below='الوقت'))
            courseDay = [item.web_element.text for item in courseDay]
            courseTime = [item.web_element.text for item in courseTime]
            examDay = [item.web_element.text for item in find_all(S("#examDayDiv"))]
            examTime = [item.web_element.text for item in find_all(S("#examTimeDiv"))]
            examDate = [item.web_element.text for item in find_all(S("#examDateDiv"))]
            lecturer = [item.web_element.text for item in find_all(S("#instructorDiv"))]
            temp_df = pd.DataFrame({'course_day':[courseDay],'course_time':[courseTime],
            'final_exam_day':[examDay[0]], 'final_exam_date':[examDate[0]],'final_exam_time':[examTime[0]],
                                   'lecturer':[lecturer]})

            time.sleep(1)
            finals_df = pd.concat([finals_df,temp_df])
            click(S(".ui-icon-close"))
    
    row = None
        
    counter +=1
    row1 = []
    row2  = []
    click(S(".pui-paginator-next"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13296\3518312580.py in <module>
#      20     # Get Final Exam, Course Day and Course Time
#      21     time.sleep(1)
# ---> 22     links = find_all((Link("التفاصيل")))
#      23     time.sleep(1)
#      24     pattern = r"\d+"
#
# ~\anaconda3\lib\site-packages\helium\__init__.py in find_all(predicate)
#     361                 leftmost_button = sorted(buttons, key=lambda button: button.x)[0]
#     362 	"""
# --> 363         return _get_api_impl().find_all_impl(predicate)
#     364
#     365 def scroll_down(num_pixels=100):
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in f_decorated(*args, **kwargs)
#      54         def f_decorated(*args, **kwargs):
#      55                 try:
# ---> 56                         return f(*args, **kwargs)
#      57                 except UnexpectedAlertPresentException:
#      58 			raise UnexpectedAlertPresentException(
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in find_all_impl(self, predicate)
#     267         @handle_unexpected_alert
#     268         def find_all_impl(self, predicate):
# --> 269 		return [
#     270                         predicate.with_impl(bound_gui_elt_impl)
#     271                         for bound_gui_elt_impl in predicate._impl.find_all()
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in <listcomp>(.0)
#     267         @handle_unexpected_alert
#     268         def find_all_impl(self, predicate):
# --> 269 		return [
#     270                         predicate.with_impl(bound_gui_elt_impl)
#     271                         for bound_gui_elt_impl in predicate._impl.find_all()
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in find_all(self)
#     614                         yield self
#     615                 else:
# --> 616                         for occurrence in self.find_all_occurrences():
#     617                                 yield self.bound_to_occurrence(occurrence)
#     618         def _is_bound(self):
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in find_all_occurrences(self)
#     720                         for frame_index in FrameIterator(self._driver):
#     721                                 search_regions = self._get_search_regions_in_curr_frame()
# --> 722                                 for occurrence in self.find_all_in_curr_frame():
#     723                                         if self._should_yield(occurrence, search_regions):
#     724                                                 occurrence.frame_index = frame_index
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in find_all_in_curr_frame(self)
#     796         def find_all_in_curr_frame(self):
#     797                 x_path = self.get_xpath()
# --> 798 		return self._sort_search_result(
#     799 			list(map(
#     800                                 WebElementWrapper, self._driver.find_elements_by_xpath(x_path)
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in _sort_search_result(self, search_result)
#     805                 for web_elt in search_result:
#     806                         try:
# --> 807                                 key = self.get_sort_index(web_elt)
#     808                         except StaleElementReferenceException:
#     809                                 pass
#
# ~\anaconda3\lib\site-packages\helium\_impl\__init__.py in get_sort_index(self, web_element)
#     817                 raise NotImplementedError()
#     818         def get_sort_index(self, web_element):
# --> 819                 return self._driver.get_distance_to_last_manipulated(web_element) + 1
#     820
#     821 class HTMLElementContainingText(HTMLElementIdentifiedByXPath):
#
# ~\anaconda3\lib\site-packages\helium\_impl\selenium_wrappers.py in get_distance_to_last_manipulated(self, web_element)
#      32                         if hasattr(self.last_manipulated_element, 'location'):
#      33                                 last_location = self.last_manipulated_element.location
# ---> 34                                 return last_location.distance_to(web_element.location)
#      35                 except StaleElementReferenceException:
#      36                         return 0
#
# ~\anaconda3\lib\site-packages\helium\_impl\selenium_wrappers.py in f_decorated(self, *args, **kwargs)
#      80         def f_decorated(self, *args, **kwargs):
#      81                 if not self.frame_index:
# ---> 82                         return f(self, *args, **kwargs)
#      83                 try:
#      84                         return f(self, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\helium\_impl\selenium_wrappers.py in f_decorated(*args, **kwargs)
#      59         def f_decorated(*args, **kwargs):
#      60                 try:
# ---> 61                         return f(*args, **kwargs)
#      62                 except URLError as url_error:
#      63                         if _is_caused_by_server_shutdown(url_error):
#
# ~\anaconda3\lib\site-packages\helium\_impl\selenium_wrappers.py in location(self)
#     104                 if self._cached_location is None:
#     105                         # Cache access to web_element.location as it's expensive:
# --> 106                         location = self.target.location
#     107                         x, y = location['x'], location['y']
#     108                         # Cache access to web_element.size as it's expensive:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in location(self)
#     533         else:
#     534             old_loc = self._execute(Command.GET_ELEMENT_LOCATION)['value']
# --> 535         new_loc = {"x": round(old_loc['x']),
#     536                    "y": round(old_loc['y'])}
#     537         return new_loc
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# ### Please Note
#
# For some cases **You will need to drop the last 10 or even more rows because it may be:**
# <li>Graduation Project</li>
# <li>Co-op training courses</li>
#
# In this case, I dropped the last nine rows  **PLEASE NOTE THAT YOU NEED TO KEEP IN MIND THE COURSES DATAFRAME AND FINALS ARE SEPERATE, IF YOU DROP SOMETHING IN COURSES, IDENTIFY ITS INDEX AND DROP IT IN FINALS**

# %%
courses_df = courses_df[:-9]
courses_df
# Out:
#   course_code  course_name section_number course_type course_hours  \
# 0     227 عال  نظم التشغيل          12320      محاضرة            3
# 0     227 عال  نظم التشغيل          12321      تمارين          ذكر
# 0     227 عال  نظم التشغيل          12328      محاضرة            3
# 0     227 عال  نظم التشغيل          12329      تمارين          ذكر
# 0     227 عال  نظم التشغيل          35605      محاضرة            3
# 0     227 عال  نظم التشغيل          35606      تمارين          ذكر
# 0     227 عال  نظم التشغيل          81787      محاضرة            3
# 0     227 عال  نظم التشغيل          81788      تمارين          ذكر
# 0     227 عال  نظم التشغيل          81901      محاضرة            3
# 0     227 عال  نظم التشغيل          81902      تمارين          ذكر
# 0     227 عال  نظم التشغيل          85788      محاضرة            3
# 0     227 عال  نظم التشغيل          85789      تمارين          ذكر
#
#   course_gender
# 0           ذكر
# 0         مغلقة
# 0           ذكر
# 0         مغلقة
# 0           ذكر
# 0         مغلقة
# 0           ذكر
# 0         مغلقة
# 0           ذكر
# 0         مغلقة
# 0           ذكر
# 0         مغلقة

# %%
finals_df = finals_df.iloc[:-9]
finals_df
# Out:
#   course_day                                 course_time final_exam_day  \
# 0   [2, 2 4]  [  08:00 ص - 09:05 ص,   09:15 ص - 10:20 ص]              3
# 0        [4]                       [  08:00 ص - 09:05 ص]            ---
# 0   [1, 1 3]  [  08:00 ص - 09:05 ص,   09:15 ص - 10:20 ص]              3
# 0        [3]                       [  08:00 ص - 09:05 ص]            ---
# 0   [4, 2 4]  [  08:00 ص - 09:05 ص,   09:15 ص - 10:20 ص]              3
# 0        [2]                       [  08:00 ص - 09:05 ص]            ---
# 0    [1 3 5]                       [  09:15 ص - 10:20 ص]              3
# 0        [3]                       [  11:45 ص - 12:50 م]            ---
# 0   [2, 2 4]  [  10:30 ص - 11:35 ص,   11:45 ص - 12:50 م]              3
# 0        [4]                       [  10:30 ص - 11:35 ص]            ---
# 0   [2 4, 4]  [  10:30 ص - 11:35 ص,   11:45 ص - 12:50 م]              3
# 0        [2]                       [  11:45 ص - 12:50 م]            ---
#
#   final_exam_date    final_exam_time                           lecturer
# 0      1444-11-24  01:00 م - 04:00 م         [مجدل سلطان مجدل بن سفران]
# 0             ---                ---         [مجدل سلطان مجدل بن سفران]
# 0      1444-11-24  01:00 م - 04:00 م                  [محمد جاويد يوسف]
# 0             ---                ---                  [محمد جاويد يوسف]
# 0      1444-11-24  01:00 م - 04:00 م  [فواز عبدالعزيز عبدالله السليمان]
# 0             ---                ---                  [محمد جاويد يوسف]
# 0      1444-11-24  01:00 م - 04:00 م          [احمد جعفر الفنوش الشبلي]
# 0             ---                ---          [احمد جعفر الفنوش الشبلي]
# 0      1444-11-24  01:00 م - 04:00 م  [فواز عبدالعزيز عبدالله السليمان]
# 0             ---                ---                  [محمد جاويد يوسف]
# 0      1444-11-24  01:00 م - 04:00 م         [مجدل سلطان مجدل بن سفران]
# 0             ---                ---         [مجدل سلطان مجدل بن سفران]

# %%
merged_courses_finals=pd.concat([courses_df,finals_df],axis=1)
merged_courses_finals
# Out:
#   course_code  course_name section_number course_type course_hours  \
# 0     227 عال  نظم التشغيل          12320      محاضرة            3
# 0     227 عال  نظم التشغيل          12321      تمارين          ذكر
# 0     227 عال  نظم التشغيل          12328      محاضرة            3
# 0     227 عال  نظم التشغيل          12329      تمارين          ذكر
# 0     227 عال  نظم التشغيل          35605      محاضرة            3
# 0     227 عال  نظم التشغيل          35606      تمارين          ذكر
# 0     227 عال  نظم التشغيل          81787      محاضرة            3
# 0     227 عال  نظم التشغيل          81788      تمارين          ذكر
# 0     227 عال  نظم التشغيل          81901      محاضرة            3
# 0     227 عال  نظم التشغيل          81902      تمارين          ذكر
# 0     227 عال  نظم التشغيل          85788      محاضرة            3
# 0     227 عال  نظم التشغيل          85789      تمارين          ذكر
#
#   course_gender course_day                                 course_time  \
# 0           ذكر   [2, 2 4]  [  08:00 ص - 09:05 ص,   09:15 ص - 10:20 ص]
# 0         مغلقة        [4]                       [  08:00 ص - 09:05 ص]
# 0           ذكر   [1, 1 3]  [  08:00 ص - 09:05 ص,   09:15 ص - 10:20 ص]
# 0         مغلقة        [3]                       [  08:00 ص - 09:05 ص]
# 0           ذكر   [4, 2 4]  [  08:00 ص - 09:05 ص,   09:15 ص - 10:20 ص]
# 0         مغلقة        [2]                       [  08:00 ص - 09:05 ص]
# 0           ذكر    [1 3 5]                       [  09:15 ص - 10:20 ص]
# 0         مغلقة        [3]                       [  11:45 ص - 12:50 م]
# 0           ذكر   [2, 2 4]  [  10:30 ص - 11:35 ص,   11:45 ص - 12:50 م]
# 0         مغلقة        [4]                       [  10:30 ص - 11:35 ص]
# 0           ذكر   [2 4, 4]  [  10:30 ص - 11:35 ص,   11:45 ص - 12:50 م]
# 0         مغلقة        [2]                       [  11:45 ص - 12:50 م]
#
#   final_exam_day final_exam_date    final_exam_time  \
# 0              3      1444-11-24  01:00 م - 04:00 م
# 0            ---             ---                ---
# 0              3      1444-11-24  01:00 م - 04:00 م
# 0            ---             ---                ---
# 0              3      1444-11-24  01:00 م - 04:00 م
# 0            ---             ---                ---
# 0              3      1444-11-24  01:00 م - 04:00 م
# 0            ---             ---                ---
# 0              3      1444-11-24  01:00 م - 04:00 م
# 0            ---             ---                ---
# 0              3      1444-11-24  01:00 م - 04:00 م
# 0            ---             ---                ---
#
#                             lecturer
# 0         [مجدل سلطان مجدل بن سفران]
# 0         [مجدل سلطان مجدل بن سفران]
# 0                  [محمد جاويد يوسف]
# 0                  [محمد جاويد يوسف]
# 0  [فواز عبدالعزيز عبدالله السليمان]
# 0                  [محمد جاويد يوسف]
# 0          [احمد جعفر الفنوش الشبلي]
# 0          [احمد جعفر الفنوش الشبلي]
# 0  [فواز عبدالعزيز عبدالله السليمان]
# 0                  [محمد جاويد يوسف]
# 0         [مجدل سلطان مجدل بن سفران]
# 0         [مجدل سلطان مجدل بن سفران]

# %%
major_you_scraped = 'cenx' # <--- change the file name based on what you want
merged_courses_finals.to_csv(f'{major_you_scraped}_combined.csv')

# %% [markdown]
# # Scraping Finished
#
# Go to the cleaning Notebook
